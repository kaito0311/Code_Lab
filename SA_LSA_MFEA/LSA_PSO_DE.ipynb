# %%
from utils.benchmark_function import *
from SaMTPSO.lsa_SaMTPSO_DE import * 

tasks = getManyTasks10()

history_cost, history_p_matrix = [], [] 
for i in range(1):

    history, p_matrix = lsa_SaMTPSO_DE(tasks, lsa= True)
    history_cost.append(history)
    history_p_matrix.append(p_matrix)
# Out:
# Epoch 721, [==============>     ]  72% ,pop_size: 420,count_de: 38, count_mutation: 0,Focus: [1.0000000000000042, 1.0, 1.0, 1.1612310933828351, 1.0000000000000047, 1.0, 1.000000000000004, 1.000000001344525, 1.0000000000242548, 1.0000000000235718],p: [9.928407595230902e-16, -2.169046755042188e-18, -1.0092271970990245e-19, 1.6045450196705437e-33, 9.449030925329577e-17, 0.5904900000000002, -4.0911951322572875e-22, 0.6042475951050021, -1.2692242453931473e-24, 0.5970179236341719],  func_val: [5.493178008787512e-23, 1.2924697071141057e-26, 1.0097419586828951e-27, 0.0, 6.400960011014954e-21, 3.907985046680551e-14, 0.0, 3.637978807091713e-12, 0.0, 37.808408859373344]44]]4]]-12, 0.0, 37.808408859373344]44]]9373344]4]]]]8408859373344]]]4]].80840885950431]]]35]]]5]6]6]819328]4]
# Sphere _dimension: 50 :  0.0
# Sphere _dimension: 50 :  9.693522803355793e-27
# Sphere _dimension: 50 :  0.0
# Weierstrass _dimension: 25 :  0.0
# Rosenbrock _dimension: 50 :  0.0
# Ackley _dimension: 50 :  2.4868995751603507e-14
# Weierstrass _dimension: 50 :  0.0
# Schewefel _dimension: 50 :  3.637978807091713e-12
# Girewank _dimension: 50 :  0.0
# Rastrigin _dimension: 50 :  37.80840885937329

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize= (20,10)) 
p_matrix = history_p_matrix[0]
for i in range(len(tasks)):
    plt.plot(np.arange(len(p_matrix)), [matrix[6-1][i] for matrix in p_matrix], label = "task " + str(i+1))
    plt.legend()

# %%
name = ["sa", "lsa", "mfea"]
fig = plt.figure(figsize = (50, 30), dpi= 100)
fig.set_facecolor("white")
color = ['r', 'b', 'y']
history = [history_cost[0]]
for task in range(NUMBER_TASKS):
    for version in range(len(history)):
        x_axis = np.arange(len(history[version]))
        y_axis =  [x[task].cost for x in history[version]]

        plt.subplot(2, int(len(tasks)/2), task+1)
        plt.plot(x_axis, y_axis, color[version], label = name[version])
        plt.yscale('log')
        plt.legend()

    plt.title(tasks[task].name)
plt.show()
